# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import bayesianinference as bi

# %%
bi.__version__
# Out:
# 'v0.2'

# %% [markdown]
# ## Example: Effect of Screener Questions on Conversion metrics
#
# * An advertiser can dropout when posting a job. How Screener Questions (SQ) affect the dropout rate? A new advertiser is fully converted if they finish posting the first job. It is a binary variable, whose distribution is completely determined by its mean. How IQ affects this mean?
# * Data is collected between 2019-02-01 and 2019-03-01.
#     * SQ: screener questions, 1 if the advertiser was shown screener question when posting the first job, otherwise 0
#     * full-conversion: 1 if the advertiser finished posting the first job

# %%
df = pd.read_csv("IQ_utility_conversion.csv")
metric, treatment = "full-conversion", "SQ"

# t means treatment (shown SQ), c means control (not shown SQ)
treatment_data = df[(df[treatment] == 1)][metric]
control_data = df[(df[treatment] == 0)][metric]

# %% [markdown]
# ## Using PYMC3 to sample from posterior distributions

# %%
model = bi.BetaBinomial(treatment_data, control_data, alpha=1, beta=1)
model.draw()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4810.14draws/s]
# The acceptance probability does not match the target. It is 0.8823789732566936, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4762.14draws/s]
# The acceptance probability does not match the target. It is 0.9057587175543301, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8973496789844887, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
model.summary_posterior_distributions()
# Out:
#                mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff  \
# treatment  0.887859  0.002354  0.000051  0.883401  0.892548  1941.720278
# control    0.890116  0.002262  0.000056  0.885909  0.894647  1635.218576
#
#                Rhat
# treatment  0.999835
# control    1.000392

# %%
# plot posterior distributions
model.plot_posterior_distributions(title = "Posterior distributions of Bernoulli mean", xmin=0, xmax=1)

# %%
model.plot_distribution_of_diff(title = "Posterior distribution of difference in Bernoulli mean", 
                               xmin = -1, xmax = 1)

# %%
model.params_vs_mcmc_sample_size()

# %%
model.prob_treatment_larger_than_control_vs_mcmc_sample_size()
# Out:
# stabilized probability that treatment is larger than control : 0.2378

# %% [markdown]
# ### Robustness against prior parameters

# %%
alpha_grid = range(1,21,2)
beta_grid = range(1,21,2)

probs = []
for alpha in alpha_grid:
    probs_sub = []
    for beta in beta_grid:
        print(alpha, beta)
        model = bi.BetaBinomial(treatment_data, control_data, alpha=alpha, beta=beta)
        model.draw()
        probs_sub.append(model.posterior_prob_treatment_larger_than_control())
    probs.append(probs_sub)
# Out:
# 1 1
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4630.11draws/s]
# The acceptance probability does not match the target. It is 0.8870403533233463, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4408.31draws/s]
# The acceptance probability does not match the target. It is 0.8893652539431383, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 3
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4743.33draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4601.27draws/s]
# The acceptance probability does not match the target. It is 0.8949211843457859, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8963190051712723, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 5
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4676.21draws/s]
# The acceptance probability does not match the target. It is 0.8892837925893464, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4410.88draws/s]
# The acceptance probability does not match the target. It is 0.8991281164965568, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 7
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4722.87draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3348.85draws/s]
# The acceptance probability does not match the target. It is 0.8959059692770774, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8791204500202595, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 9
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3636.37draws/s]
# The acceptance probability does not match the target. It is 0.8992674931153689, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8985871955576692, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3767.26draws/s]
# The acceptance probability does not match the target. It is 0.902382870919242, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8803957551528082, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 11
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4424.67draws/s]
# The acceptance probability does not match the target. It is 0.89308096100778, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4501.03draws/s]
# The acceptance probability does not match the target. It is 0.8857607005834116, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 13
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4652.43draws/s]
# The acceptance probability does not match the target. It is 0.8798303156456722, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9017079173075604, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4724.13draws/s]
# The acceptance probability does not match the target. It is 0.8861823903362132, but should be close to 0.8. Try to increase the number of tuning steps.
# 1 15
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4365.07draws/s]
# The acceptance probability does not match the target. It is 0.8863834073001748, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4560.42draws/s]
# 11 13
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4630.03draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4258.18draws/s]
# 11 15
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4260.33draws/s]
# The acceptance probability does not match the target. It is 0.9013284207129192, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8858589561628379, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4728.09draws/s]
# The acceptance probability does not match the target. It is 0.878937576305416, but should be close to 0.8. Try to increase the number of tuning steps.
# 11 17
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4644.14draws/s]
# The acceptance probability does not match the target. It is 0.8944403703285627, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8963103003957805, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4618.15draws/s]
# The acceptance probability does not match the target. It is 0.8871486990919016, but should be close to 0.8. Try to increase the number of tuning steps.
# 11 19
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4657.87draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4513.01draws/s]
# The acceptance probability does not match the target. It is 0.8824741716849461, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8817789589792779, but should be close to 0.8. Try to increase the number of tuning steps.
# 13 1
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4602.24draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4627.53draws/s]
# 13 3
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4714.00draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4596.96draws/s]
# The acceptance probability does not match the target. It is 0.8826572831370589, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8885551246153549, but should be close to 0.8. Try to increase the number of tuning steps.
# 13 5
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4492.37draws/s]
# The acceptance probability does not match the target. It is 0.8851964399214254, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8882575999679492, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4710.61draws/s]
# 13 7
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4681.39draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4549.67draws/s]
# 13 9
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4613.64draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4543.89draws/s]
# The acceptance probability does not match the target. It is 0.8821916546603344, but should be close to 0.8. Try to increase the number of tuning steps.
# 13 11
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4572.04draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4693.55draws/s]
# The acceptance probability does not match the target. It is 0.8793933361482216, but should be close to 0.8. Try to increase the number of tuning steps.
# 13 13
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4597.12draws/s]
# The acceptance probability does not match the target. It is 0.8815638037573922, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4371.32draws/s]
# The acceptance probability does not match the target. It is 0.887197765381473, but should be close to 0.8. Try to increase the number of tuning steps.
# ...
# The acceptance probability does not match the target. It is 0.8787754362594428, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4548.05draws/s]
# The acceptance probability does not match the target. It is 0.8932794022822901, but should be close to 0.8. Try to increase the number of tuning steps.
# 15 11
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4694.46draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4671.34draws/s]
# The acceptance probability does not match the target. It is 0.8941467561704971, but should be close to 0.8. Try to increase the number of tuning steps.
# 15 13
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4649.54draws/s]
# The acceptance probability does not match the target. It is 0.8852039460021617, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4555.06draws/s]
# The acceptance probability does not match the target. It is 0.8898663422391023, but should be close to 0.8. Try to increase the number of tuning steps.
# 15 15
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4671.29draws/s]
# The acceptance probability does not match the target. It is 0.88540844937494, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4656.22draws/s]
# 15 17
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4531.51draws/s]
# The acceptance probability does not match the target. It is 0.889910605418922, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8797386322511381, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3594.95draws/s]
# 15 19
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4578.47draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3727.98draws/s]
# The acceptance probability does not match the target. It is 0.891719717456545, but should be close to 0.8. Try to increase the number of tuning steps.
# 17 1
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4481.52draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4664.57draws/s]
# 17 3
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4580.91draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4200.74draws/s]
# The acceptance probability does not match the target. It is 0.8911127693396722, but should be close to 0.8. Try to increase the number of tuning steps.
# 17 5
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3696.55draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3104.44draws/s]
# The acceptance probability does not match the target. It is 0.8980155035306662, but should be close to 0.8. Try to increase the number of tuning steps.
# 17 7
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4328.38draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3581.27draws/s]
# 17 9
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3499.07draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3700.50draws/s]
# The acceptance probability does not match the target. It is 0.8855457584396201, but should be close to 0.8. Try to increase the number of tuning steps.
# 17 11
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4558.79draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4386.68draws/s]
# The acceptance probability does not match the target. It is 0.8824596420300852, but should be close to 0.8. Try to increase the number of tuning steps.
# 17 13
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3123.46draws/s]
# The acceptance probability does not match the target. It is 0.8819054064511272, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3599.91draws/s]
# 17 15
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3486.92draws/s]
# The acceptance probability does not match the target. It is 0.8851468876721197, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8898934376442257, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4570.28draws/s]
# 17 17
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4496.08draws/s]
# The acceptance probability does not match the target. It is 0.911383301793525, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4010.49draws/s]
# 17 19
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3617.69draws/s]
# The acceptance probability does not match the target. It is 0.8919417980637205, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3706.55draws/s]
# The acceptance probability does not match the target. It is 0.906523119437673, but should be close to 0.8. Try to increase the number of tuning steps.
# 19 1
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3566.67draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3716.33draws/s]
# 19 3
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4515.30draws/s]
# The acceptance probability does not match the target. It is 0.8849274709675425, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4053.78draws/s]
# 19 5
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3222.47draws/s]
# The acceptance probability does not match the target. It is 0.8812145920259526, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3567.73draws/s]
# 19 7
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3777.83draws/s]
# The acceptance probability does not match the target. It is 0.8841935781767146, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4596.06draws/s]
# 19 9
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4641.50draws/s]
# The acceptance probability does not match the target. It is 0.8810932865979233, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3750.00draws/s]
# 19 11
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3441.00draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3048.97draws/s]
# 19 13
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3528.30draws/s]
# The acceptance probability does not match the target. It is 0.881455015732576, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8918634635189492, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4533.46draws/s]
# The acceptance probability does not match the target. It is 0.8946570608234518, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8870193116901798, but should be close to 0.8. Try to increase the number of tuning steps.
# 19 15
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4064.17draws/s]
# The acceptance probability does not match the target. It is 0.8812515188263401, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 3513.70draws/s]
# The acceptance probability does not match the target. It is 0.8960547437049785, but should be close to 0.8. Try to increase the number of tuning steps.
# 19 17
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4171.50draws/s]
# The acceptance probability does not match the target. It is 0.888313219918527, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4201.69draws/s]
# 19 19
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4553.24draws/s]
# The acceptance probability does not match the target. It is 0.8804429108970195, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [Bernoulli mean]
# Sampling 2 chains: 100%|██████████| 6000/6000 [00:01<00:00, 4599.34draws/s]

# %%
robust_mat = pd.DataFrame(probs, columns =[str(beta) for beta in beta_grid])
robust_mat.index=alpha_grid
robust_mat.index.name ="alpha/beta"
robust_mat.reset_index()
robust_mat
# Out:
#                  1       3       5       7       9      11      13      15  \
# alpha/beta
# 1           0.2370  0.2342  0.2332  0.2368  0.2462  0.2372  0.2368  0.2394
# 3           0.2506  0.2496  0.2336  0.2336  0.2372  0.2330  0.2260  0.2424
# 5           0.2196  0.2290  0.2366  0.2306  0.2472  0.2378  0.2278  0.2370
# 7           0.2412  0.2330  0.2454  0.2206  0.2316  0.2356  0.2266  0.2402
# 9           0.2352  0.2400  0.2372  0.2362  0.2308  0.2370  0.2448  0.2416
# 11          0.2322  0.2468  0.2334  0.2358  0.2380  0.2326  0.2532  0.2356
# 13          0.2464  0.2262  0.2348  0.2452  0.2296  0.2470  0.2402  0.2458
# 15          0.2240  0.2548  0.2382  0.2350  0.2436  0.2370  0.2286  0.2374
# 17          0.2264  0.2286  0.2310  0.2342  0.2270  0.2282  0.2284  0.2472
# 19          0.2224  0.2304  0.2482  0.2254  0.2358  0.2256  0.2396  0.2422
#
#                 17      19
# alpha/beta
# 1           0.2386  0.2406
# 3           0.2352  0.2396
# 5           0.2274  0.2294
# 7           0.2410  0.2306
# 9           0.2326  0.2584
# 11          0.2260  0.2336
# 13          0.2372  0.2366
# 15          0.2378  0.2448
# 17          0.2372  0.2326
# 19          0.2276  0.2398
